# %%
# !uv add xmltodict
# Out:
# Resolved 34 packages in 696ms
# Prepared 1 package in 66ms
# Installed 1 package in 26ms
#  + xmltodict==1.0.4

# %%
import requests
import json
import xmltodict

serviceKey = ''
url = 'http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList'
params ={'serviceKey' : serviceKey, 'YM' : '201201', 'NAT_CD' : '112', 'ED_CD' : 'E' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><responseTime>2026-07-24T15:46:25.360+09:00</responseTime><resultCode>30</resultCode><resultMsg>SERVICE KEY IS NOT REGISTERED ERROR.</resultMsg></header></response>'
